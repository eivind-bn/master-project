# %%
from xai import *
import matplotlib.pyplot as plt
import random
import numpy as np
import torch
import os
from tqdm import tqdm

# %%
save_folder = "./images/mnist-eap-explanation-v3"
samples_path = "images/samples-v2"
latent_dim = 8
rows = 10
columns = 13

# %%
try:
    mnist = MNIST.load("mnist.model")
except FileNotFoundError:
    mnist = MNIST(
        latent_shape=(latent_dim,), 
        hidden_layers=2, 
        classifier_head_output_activation="Softmax",
        ) 
    
    mnist.fit_autoencoder(
        epochs=10_000,
        batch_size=256,
        loss_criterion="MSELoss",
        early_stop_cont=750,
        verbose=True,
        info="Mnist autoencoder train"
    )

    mnist.fit_classifier_head(
        epochs=10_000,
        batch_size=256,
        early_stop_cont=750,
        verbose=True,
        info="Mnist classifier-head train"
    )

    mnist.save("mnist.model")

# %%
mnist.autoencoder.train_history.figure("Mnist autoencoder train")

# %%
mnist.classifier_head.train_history.figure("Mnist classifier-head train")

# %%
try:
    os.mkdir(save_folder)
except:
    pass

for algorithm in ["exact", "permutation", "deep", "kernel", "gradient"]:
    try:
        os.mkdir(f"{save_folder}/{algorithm}")
    except:
        pass

try:
    samples = Stream.load(samples_path, Tuple[torch.Tensor,torch.Tensor]).list()
except:
    samples: List[Tuple[torch.Tensor,torch.Tensor]] = []
    for i in range(rows):
        samples.append(mnist.get_sample(digit=i))

    Stream(samples).save(samples_path)

# %%
def mk_shap_latent_plot(algorithm: Explainers):
    fig = plt.figure(dpi=150, figsize=(26,22)) 
    fig.suptitle(f"Algorithm: {algorithm.capitalize()}Explainer", size=30)

    def save_mnist(image: np.ndarray, path: str, **args) -> None:
        plt.imsave(path, image.repeat(16,0).repeat(16,1), **args)

    compute_times = []

    with tqdm(total=rows, desc=f"{algorithm.capitalize()}Explainer") as bar:
        for row in range(rows):
            slot = row*columns

            sample,label = samples[row]
            sample = sample.numpy(force=True)
            label = int(label.item())
            predict = mnist(sample)
            recon = predict.reconstruction().numpy(force=True)
            probabilities = predict.classification().tolist()

            latent_explanation = predict.reconstruction.explain(algorithm, mnist(mnist.val_data).embedding()).flatten()
            classification_explanation = predict.classification.explain(algorithm, mnist(mnist.val_data).embedding()).flatten()

            latent_shap = latent_explanation.shap_values
            cls_shap = classification_explanation.shap_values

            weights = np.abs(latent_shap)/np.sum(np.abs(latent_shap), axis=0)
            shap_values: np.ndarray = cls_shap@weights.T
            shap_values = shap_values.reshape((10,28,28))
            shap_sum = shap_values.sum(0)
            norm = max([np.max(np.abs(shap_values)), np.max(np.abs(shap_sum))])

            compute_times.append((latent_explanation.compute_time + classification_explanation.compute_time).seconds().float())

            fig.add_subplot(rows,columns,slot+1)
            plt.imshow(sample, cmap="gray")
            plt.axis('off')
            plt.title(f"$x={{{label}}}$", size=25)
            save_mnist(sample, f"{save_folder}/{algorithm}/sample{row}.png", cmap="gray")
                
            fig.add_subplot(rows,columns,slot+2)
            plt.imshow(recon, cmap="gray")
            plt.axis('off')
            if row == 0:
                plt.title("$\hat{{x}}$", size=25)
            save_mnist(recon, f"{save_folder}/{algorithm}/reconstruction{row}.png", cmap="gray")

            for j,shap in enumerate(shap_values):
                fig.add_subplot(rows,columns,slot+j+3)
                im = np.zeros((28,28,3), dtype=np.float32)
                red = np.where(shap > 0, shap/norm, np.zeros_like(shap))
                blue = np.where(shap < 0, -shap/norm, np.zeros_like(shap))
                im[:,:,0] = red
                im[:,:,2] = blue
                plt.imshow(im)
                plt.axis('off')
                if row == 0:
                    plt.title(f"$c_{j}$\n${probabilities[j]*100:.2f}$%", size=25)
                else:
                    plt.title(f"${probabilities[j]*100:.2f}$%", size=25)
                save_mnist(im, f"{save_folder}/{algorithm}/eap{j}-explanation.png")
            
            bar.update()

            im = np.zeros((28,28,3), dtype=np.float32)
            red = np.where(shap_sum > 0, shap_sum/norm, np.zeros_like(shap_sum))
            blue = np.where(shap_sum < 0, -shap_sum/norm, np.zeros_like(shap_sum))
            im[:,:,0] = red
            im[:,:,2] = blue
            fig.add_subplot(rows,columns,slot+j+4)
            plt.imshow(im)
            plt.axis('off')
            if row == 0:
                plt.title(f"$\sum_{{i=0}}^{{9}}c_i$", size=25)
            save_mnist(im, f"{save_folder}/{algorithm}/eap-sum{row}.png")



    fig.tight_layout()
    fig.savefig(f"{save_folder}/{algorithm}/classification-{algorithm}-explanation.png", bbox_inches="tight")

    plt.figure()
    plt.plot(range(len(compute_times)), compute_times, label="Time used")
    plt.plot(range(len(compute_times)), [sum(compute_times)/len(compute_times)]*len(compute_times), label="Average time")
    plt.legend()
    plt.ylabel("Seconds")
    plt.xlabel("Iteration")
    plt.title(f"Compute times: {algorithm}")
    plt.savefig(f"{save_folder}/{algorithm}/compute-times.png")


algorithm: Explainers
for algorithm in ["exact", "permutation", "deep", "kernel", "gradient"]:
    mk_shap_latent_plot(algorithm)
# Out:
# ExactExplainer:   0%|          | 0/10 [00:00<?, ?it/s]CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
# ExactExplainer: 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]
# PermutationExplainer:  30%|███       | 3/10 [00:01<00:03,  2.09it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 94
#      92 algorithm: Explainers
#      93 for algorithm in ["exact", "permutation", "deep", "kernel", "gradient"]:
# ---> 94     mk_shap_latent_plot(algorithm)
#
# Cell In[5], line 61, in mk_shap_latent_plot(algorithm)
#      59     else:
#      60         plt.title(f"${probabilities[j]*100:.2f}$%", size=25)
# ---> 61     save_mnist(im, f"{save_folder}/{algorithm}/eap{j}-explanation.png")
#      63 bar.update()
#      65 im = np.zeros((28,28,3), dtype=np.float32)
#
# Cell In[5], line 6, in mk_shap_latent_plot.<locals>.save_mnist(image, path, **args)
#       5 def save_mnist(image: np.ndarray, path: str, **args) -> None:
# ----> 6     plt.imsave(path, image.repeat(16,0).repeat(16,1), **args)
#
# File ~/master-project/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:2396, in imsave(fname, arr, **kwargs)
#    2392 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2393 def imsave(
#    2394     fname: str | os.PathLike | BinaryIO, arr: ArrayLike, **kwargs
#    2395 ) -> None:
# -> 2396     matplotlib.image.imsave(fname, arr, **kwargs)
#
# File ~/master-project/.venv/lib/python3.11/site-packages/matplotlib/image.py:1617, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1615     sm = cm.ScalarMappable(cmap=cmap)
#    1616     sm.set_clim(vmin, vmax)
# -> 1617     rgba = sm.to_rgba(arr, bytes=True)
#    1618 if pil_kwargs is None:
#    1619     pil_kwargs = {}
#
# File ~/master-project/.venv/lib/python3.11/site-packages/matplotlib/cm.py:490, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     488     raise ValueError("Third dimension must be 3 or 4")
#     489 if xx.dtype.kind == 'f':
# --> 490     if norm and (xx.max() > 1 or xx.min() < 0):
#     491         raise ValueError("Floating point image RGB values "
#     492                          "must be in the 0..1 range.")
#     493     if bytes:
#
# File ~/master-project/.venv/lib/python3.11/site-packages/numpy/core/_methods.py:43, in _amin(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
#      41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
# ---> 43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#
# KeyboardInterrupt:
